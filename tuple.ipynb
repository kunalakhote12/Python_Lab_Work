# %%
my_tuple=()
my_tuple #or print(my_tuple)
# Out:
# ()

# %%
my_tuple=(1,2,3)
my_tuple
# Out:
# (1, 2, 3)

# %%
my_tuple=(1,"hello",3.14)
my_tuple
# Out:
# (1, 'hello', 3.14)

# %%
#nested tuple
my_tuple=('house',[1,4,5],(3.14,5.5,60.5))
my_tuple
# Out:
# ('house', [1, 4, 5], (3.14, 5.5, 60.5))

# %%
my_tuple=4,5.4,"dog"
my_tuple
# Out:
# (4, 5.4, 'dog')

# %%
#unpacking
a,b,c=my_tuple
print(a," ",b," ",c)
# Out:
# 4   5.4   dog

# %%
a,b,c=4,3.14,'hello'
print(a," ",b," ",c)
# Out:
# 4   3.14   hello

# %%
my_tuple=("HEllo")
print(type(my_tuple))
# Out:
# <class 'str'>

# %%
my_tuple=("HEllo",)
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
my_tuple=("c","s","i","t","b","r","a","n","c","h")
print(my_tuple[0])
# print(my_tuple[2.0]) will give as we cannot give index as float value
# Out:
# c

# %%
#my_tuple[0]='d' and del my_tuple[2] wil give error as tuples are immutable
t1=(5,3.14,"hello")
t2=([1,2,6],"rat",(7.1,5.58,8.05))
t3=t1+t2
t3
# Out:
# (5, 3.14, 'hello', [1, 2, 6], 'rat', (7.1, 5.58, 8.05))

# %%
my_tuple=('house',[1,4,5],(7,3,9))
print(my_tuple[1][0])
print(my_tuple[2][2])
print(my_tuple[-1])
print(my_tuple[-1][-1])
print(my_tuple[:])
print(my_tuple[:-2])
print(my_tuple[-2:-2])
# Out:
# 1
# 9
# (7, 3, 9)
# 9
# ('house', [1, 4, 5], (7, 3, 9))
# ('house',)
# ()

# %%
print((1,2,3)+(4,5,6))
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(('repeat',)*5)
print((1)*5)
print((1,)*6)
# Out:
# ('repeat', 'repeat', 'repeat', 'repeat', 'repeat')
# 5
# (1, 1, 1, 1, 1, 1)

# %%
my_tuple=(4,5,7)
del my_tuple
type(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-549d27529c67> in <module>()
#       1 my_tuple=(4,5,7)
#       2 del my_tuple
# ----> 3 type(my_tuple)
#
# NameError: name 'my_tuple' is not defined

# %%
my_tuple=('a','p','p','l','e')
my_tuple.count('p')
# Out:
# 2

# %%
print(my_tuple.index('a'))
print(my_tuple.index('l'))
print(my_tuple.index('p'))
# Out:
# 0
# 3
# 1

# %%
print('a' in my_tuple)
print('b' in my_tuple)
# Out:
# True
# False

# %%
for i in ('CSIT','Acropolis'):
  print("Hello ",i)
# Out:
# Hello  CSIT
# Hello  Acropolis

# %%
a=(1,2,3)
for i in a:
  print(i**2)
# Out:
# 1
# 4
# 9

# %%
# a.sort() will not work in tuple as tuple are immutable
b=sorted (a)
b
# Out:
# [1, 2, 3]
